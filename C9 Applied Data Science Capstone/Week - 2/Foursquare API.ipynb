# %% [markdown]
# # 1. Introduction to Foursquare

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## [Four Square](https://www.Foursquare.com)

# %% [markdown]
# # 2. Getting Foursquare API Credentials

# %% [markdown]
# ## 2.1 Signing up for a Foursquare Developer Account

# %% [markdown]
# # 3. Using Foursquare API

# %% [markdown]
# ## 3.1 Foursquare - Search

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.2 Foursquare - Explore and Other Queries

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.3 Foursquare - Summary

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import folium
